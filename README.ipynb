# %% [markdown]
# 📚 StoryWeaver: Un Generador de Cuentos Infantiles con IA
# 📝 Resumen
#
# StoryWeaver es una prueba de concepto (POC) desarrollada en Jupyter Notebook que combina la inteligencia artificial con la narrativa infantil.
# El proyecto utiliza el modelo Gemini 1.5 Flash para generar cuentos cortos y personalizados para niños, y además produce un prompt optimizado de imagen para ilustrar la primera escena de la historia en plataformas como Nightcafe.
#
# Este proyecto busca mostrar cómo la IA puede servir como herramienta educativa, creativa y artística al mismo tiempo.
#
# 🎯 Introducción
#
# Nombre del Proyecto: StoryWeaver – Generador de Cuentos Infantiles con IA
#
# Problema
#
# Muchos docentes y padres encuentran difícil motivar a los niños pequeños con lecturas personalizadas y que además incluyan recursos visuales atractivos.
# La creación de cuentos adaptados a cada niño demanda tiempo, creatividad y recursos, lo que no siempre está al alcance.
#
# Relevancia
#
# El aprendizaje en la infancia temprana mejora cuando se combina narrativa personalizada + ilustraciones llamativas. Usar IA para asistir en esta tarea puede ahorrar tiempo y ofrecer un recurso educativo innovador.
#
# 💡 Propuesta de Solución
#
# El proyecto utiliza dos capacidades de la IA:
#
# Texto → Texto: generación de un cuento corto, didáctico y positivo, adaptado a un tema y personaje ingresados por el usuario.
#
# Texto → Imagen: creación de un prompt detallado y conciso que represente la primera escena del cuento, listo para usarse en Nightcafe o cualquier generador de imágenes IA.
#
# De esta forma, el usuario obtiene una historia completa y un recurso visual para acompañarla.
#
# ✅ Viabilidad
#
# Tiempo: es factible en un entorno educativo porque solo requiere Jupyter Notebook, conexión a internet y una clave API.
#
# Recursos: se utiliza Gemini (texto) y un generador de imágenes gratuito (Nightcafe), por lo que no hay costos adicionales.
#
# Simplicidad: la implementación se limita a un único notebook, fácil de ejecutar.
#
# 🎯 Objetivos
#
# Diseñar un generador de cuentos infantiles con IA.
#
# Producir prompts de imágenes listos para ilustrar la primera escena.
#
# Demostrar el uso de técnicas de fast prompting para obtener resultados claros, breves y educativos.
#
# Proveer un recurso innovador para docentes y familias.
#
# 🛠️ Metodología
#
# Se definió un contexto pedagógico en los prompts (“Actúa como un escritor de cuentos para niños pequeños”).
#
# Se optimizaron las instrucciones con fast prompting (estructura clara, formato fijo para el prompt de imagen).
#
# Se ejecutó la prueba en un Jupyter Notebook, integrando narrativa (texto) y visualización (prompts para imágenes).
#
# ⚙️ Herramientas y Tecnologías
#
# Gemini 1.5 Flash → generación de texto.
#
# Nightcafe (u otro generador) → generación de imágenes con el prompt IA.
#
# Jupyter Notebook → entorno de desarrollo interactivo.
#
# Python → lenguaje de implementación.
#
# 📊 Resultados
#
# Se genera un cuento infantil adaptado al tema y personaje elegido.
#
# Se produce un prompt optimizado para que cualquier herramienta de texto→imagen pueda crear la primera ilustración.
#
# La implementación cumple con la solución propuesta: estimular la imaginación y el aprendizaje de los niños.
#
# 🏁 Conclusiones
#
# El proyecto logró integrar de manera sencilla IA de texto y visual en un recurso educativo.
#
# Se cumplieron los objetivos planteados: cuentos personalizados, prompts de imagen y demostración de fast prompting.
#
# Es un punto de partida para escalar hacia plataformas más completas (app web o móvil educativa).
#
# 📚 Referencias
#
# Google AI – Gemini API Documentation.
#
# Nightcafe Studio – Text-to-Image Generator.
#
# Recursos del curso “IA: Entretejiendo Imaginación y Algoritmos”.
